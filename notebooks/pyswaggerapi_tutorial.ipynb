# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
def set_cwd_to_root(root_name: str = "PySwaggerAPIWrap") -> None:
    """
    :param root_name: Name of the root directory of the project.
    :return:

    Sets the current working directory to the root directory of the project.
    """
    new_wd = os.path.join(os.getcwd().split(root_name)[0], root_name)
    os.chdir(new_wd)

set_cwd_to_root()

# %%
from PySwaggerAPIWrap.http_client import HttpClient
from PySwaggerAPIWrap.api_filter import APIDataFrameFilter
import pandas as pd 
import numpy as np

# %%
ENDPOINT = "https://petstore.swagger.io/v2"
AUTH_TOKEN = "special-key"

# %%
http_client = HttpClient(base_url=ENDPOINT, auth_token=AUTH_TOKEN)

# %%
routes_dict = http_client.get_routes_df(swagger_route="/swagger.json")
routes_dict
# Out:
# C:\Users\KlajdiBeqiraj\miniconda3\envs\pyswag\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'petstore.swagger.io'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#    api_type                     route  method  \
# 0       pet  /pet/{petId}/uploadImage    POST
# 1       pet                      /pet    POST
# 2       pet                      /pet     PUT
# 3       pet         /pet/findByStatus     GET
# 4       pet           /pet/findByTags     GET
# 5       pet              /pet/{petId}     GET
# 6       pet              /pet/{petId}    POST
# 7       pet              /pet/{petId}  DELETE
# 8     store          /store/inventory     GET
# 9     store              /store/order    POST
# 10    store    /store/order/{orderId}     GET
# 11    store    /store/order/{orderId}  DELETE
# 12     user      /user/createWithList    POST
# 13     user          /user/{username}     GET
# 14     user          /user/{username}     PUT
# 15     user          /user/{username}  DELETE
# 16     user               /user/login     GET
# 17     user              /user/logout     GET
# 18     user     /user/createWithArray    POST
# 19     user                     /user    POST
#
#                                            parameters
# 0   [{'name': 'petId', 'param_type': 'integer', 'i...
# 1   [{'name': 'body', 'param_type': None, 'is_requ...
# 2   [{'name': 'body', 'param_type': None, 'is_requ...
# 3   [{'name': 'status', 'param_type': 'array', 'is...
# 4   [{'name': 'tags', 'param_type': 'array', 'is_r...
# 5   [{'name': 'petId', 'param_type': 'integer', 'i...
# 6   [{'name': 'petId', 'param_type': 'integer', 'i...
# 7   [{'name': 'api_key', 'param_type': 'string', '...
# 8                                                  []
# 9   [{'name': 'body', 'param_type': None, 'is_requ...
# 10  [{'name': 'orderId', 'param_type': 'integer', ...
# 11  [{'name': 'orderId', 'param_type': 'integer', ...
# 12  [{'name': 'body', 'param_type': 'array', 'is_r...
# 13  [{'name': 'username', 'param_type': 'string', ...
# 14  [{'name': 'username', 'param_type': 'string', ...
# 15  [{'name': 'username', 'param_type': 'string', ...
# 16  [{'name': 'username', 'param_type': 'string', ...
# 17                                                 []
# 18  [{'name': 'body', 'param_type': 'array', 'is_r...
# 19  [{'name': 'body', 'param_type': None, 'is_requ...

# %%
api_filter = APIDataFrameFilter(routes_dict)

# %%
api_filter.filter(method="GET")
# Out:
#    api_type                   route method  \
# 3       pet       /pet/findByStatus    GET
# 4       pet         /pet/findByTags    GET
# 5       pet            /pet/{petId}    GET
# 8     store        /store/inventory    GET
# 10    store  /store/order/{orderId}    GET
# 13     user        /user/{username}    GET
# 16     user             /user/login    GET
# 17     user            /user/logout    GET
#
#                                            parameters  \
# 3   [{'name': 'status', 'param_type': 'array', 'is...
# 4   [{'name': 'tags', 'param_type': 'array', 'is_r...
# 5   [{'name': 'petId', 'param_type': 'integer', 'i...
# 8                                                  []
# 10  [{'name': 'orderId', 'param_type': 'integer', ...
# 13  [{'name': 'username', 'param_type': 'string', ...
# 16  [{'name': 'username', 'param_type': 'string', ...
# 17                                                 []
#
#                                             api_route
# 3   APIRoute(\n\troute=/pet/findByStatus, \n\tmeth...
# 4   APIRoute(\n\troute=/pet/findByTags, \n\tmethod...
# 5   APIRoute(\n\troute=/pet/{petId}, \n\tmethod=GE...
# 8   APIRoute(\n\troute=/store/inventory, \n\tmetho...
# 10  APIRoute(\n\troute=/store/order/{orderId}, \n\...
# 13  APIRoute(\n\troute=/user/{username}, \n\tmetho...
# 16  APIRoute(\n\troute=/user/login, \n\tmethod=GET...
# 17  APIRoute(\n\troute=/user/logout, \n\tmethod=GE...

# %%
dir(api_filter.pet.get_with_petId)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'copy',
#  'define_params',
#  'from_dict',
#  'generate_call_method',
#  'method',
#  'parameters',
#  'route',
#  'route_type',
#  'run',
#  'run_api',
#  'validate_params']

# %%
api_filter.filter(method="GET")
# Out:
#    api_type                   route method  \
# 3       pet       /pet/findByStatus    GET
# 4       pet         /pet/findByTags    GET
# 5       pet            /pet/{petId}    GET
# 8     store        /store/inventory    GET
# 10    store  /store/order/{orderId}    GET
# 13     user        /user/{username}    GET
# 16     user             /user/login    GET
# 17     user            /user/logout    GET
#
#                                            parameters  \
# 3   [{'name': 'status', 'param_type': 'array', 'is...
# 4   [{'name': 'tags', 'param_type': 'array', 'is_r...
# 5   [{'name': 'petId', 'param_type': 'integer', 'i...
# 8                                                  []
# 10  [{'name': 'orderId', 'param_type': 'integer', ...
# 13  [{'name': 'username', 'param_type': 'string', ...
# 16  [{'name': 'username', 'param_type': 'string', ...
# 17                                                 []
#
#                                             api_route
# 3   APIRoute(\n\troute=/pet/findByStatus, \n\tmeth...
# 4   APIRoute(\n\troute=/pet/findByTags, \n\tmethod...
# 5   APIRoute(\n\troute=/pet/{petId}, \n\tmethod=GE...
# 8   APIRoute(\n\troute=/store/inventory, \n\tmetho...
# 10  APIRoute(\n\troute=/store/order/{orderId}, \n\...
# 13  APIRoute(\n\troute=/user/{username}, \n\tmetho...
# 16  APIRoute(\n\troute=/user/login, \n\tmethod=GET...
# 17  APIRoute(\n\troute=/user/logout, \n\tmethod=GE...

# %%
data = api_filter.store.get_inventory.run(http_client)
data
# Out:
# [autoreload of PySwaggerAPIWrap.http_client failed: Traceback (most recent call last):
#   File "C:\Users\KlajdiBeqiraj\miniconda3\envs\pyswag\lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\KlajdiBeqiraj\miniconda3\envs\pyswag\lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\KlajdiBeqiraj\miniconda3\envs\pyswag\lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\KlajdiBeqiraj\miniconda3\envs\pyswag\lib\site-packages\IPython\extensions\autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "C:\Users\KlajdiBeqiraj\miniconda3\envs\pyswag\lib\site-packages\IPython\extensions\autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'HttpClient' object layout differs from 'HttpClient'
# ]
# C:\Users\KlajdiBeqiraj\miniconda3\envs\pyswag\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'petstore.swagger.io'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'sold': 9,
#  '66363': 2,
#  'BPksnQx1oalC9IhhUfUc4lpFlfB0rht0N8IJsBgthNaqdrj43uk0YX48yzYadN81gZAYYDEjTBaqMOhLogiBmZbAoh1sVuN77FPmnKSpMrgsv3lsBFbFyNOBRbY4QllcbvR6OtnK0gsYKmp2uaGwx9E5dWLSd0KcT2O6jfWBqlf1WUXOJ3y1tSevyIN2RBio2Pv4VQqV4g2qFmiMeCLnESxnLY4Y37PbS4d8sGyp9HmdYGSPcABDQUZhjzva7qI': 2,
#  'string': 261,
#  'pKEOm5831.422150269268744D4W': 2,
#  '46673': 2,
#  'pending': 3,
#  'available': 351,
#  '...': 2,
#  'wlcwbJFw1P': 2,
#  'oNw0': 12,
#  'fT42D6BZdm': 1,
#  'SOLD': 1,
#  '=2': 2,
#  'invalid_status': 1,
#  ':2': 2,
#  '...': 2,
#  'j8rUgCA680.50590458135171.60975683573379370N77C': 2}

# %%
data = api_filter.pet.get_with_petId.run(http_client=http_client, petId=1)
data
# Out:
# C:\Users\KlajdiBeqiraj\miniconda3\envs\pyswag\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'petstore.swagger.io'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'id': 1,
#  'category': {'id': 3, 'name': 'Snake'},
#  'name': 'Orochimaru',
#  'photoUrls': [''],
#  'tags': [{'id': 303, 'name': 'Orochimaru'}],
#  'status': 'sold'}
